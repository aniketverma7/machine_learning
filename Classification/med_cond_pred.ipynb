# %%
import pandas as pd

df = pd.read_csv('datasets/medical_conditions_dataset.csv')
df
# Out:
#          id  full_name   age  gender smoking_status        bmi  \
# 0         1   User0001   NaN    male     Non-Smoker        NaN
# 1         2   User0002  30.0    male     Non-Smoker        NaN
# 2         3   User0003  18.0    male     Non-Smoker  35.612486
# 3         4   User0004   NaN    male     Non-Smoker        NaN
# 4         5   User0005  76.0    male     Non-Smoker        NaN
# ...     ...        ...   ...     ...            ...        ...
# 9995   9996   User9996   NaN    male     Non-Smoker  25.029002
# 9996   9997   User9997   NaN    male     Non-Smoker  27.017487
# 9997   9998   User9998  23.0    male         Smoker        NaN
# 9998   9999   User9999   NaN  female     Non-Smoker        NaN
# 9999  10000  User10000  27.0    male     Non-Smoker  25.454891
#
#       blood_pressure  glucose_levels  condition
# 0                NaN             NaN  Pneumonia
# 1         105.315064             NaN   Diabetic
# 2                NaN             NaN  Pneumonia
# ...

# %%
df = df.drop(['id'], axis='columns')
df = df.drop(['full_name'], axis='columns')
df
# Out:
#        age  gender smoking_status        bmi  blood_pressure  glucose_levels  \
# 0      NaN    male     Non-Smoker        NaN             NaN             NaN
# 1     30.0    male     Non-Smoker        NaN      105.315064             NaN
# 2     18.0    male     Non-Smoker  35.612486             NaN             NaN
# 3      NaN    male     Non-Smoker        NaN       99.119829             NaN
# 4     76.0    male     Non-Smoker        NaN             NaN             NaN
# ...    ...     ...            ...        ...             ...             ...
# 9995   NaN    male     Non-Smoker  25.029002      152.540355      137.551451
# 9996   NaN    male     Non-Smoker  27.017487             NaN             NaN
# 9997  23.0    male         Smoker        NaN      148.833321      173.931480
# 9998   NaN  female     Non-Smoker        NaN             NaN             NaN
# 9999  27.0    male     Non-Smoker  25.454891             NaN      196.083267
#
#       condition
# 0     Pneumonia
# ...

# %%
df['bmi'] = df['bmi'].fillna(df['bmi'].mean())
df['glucose_levels'] = df['glucose_levels'].fillna(df['glucose_levels'].mean())
df
# Out:
#        age  gender smoking_status        bmi  blood_pressure  glucose_levels  \
# 0      NaN    male     Non-Smoker  27.423420             NaN      135.219608
# 1     30.0    male     Non-Smoker  27.423420      105.315064      135.219608
# 2     18.0    male     Non-Smoker  35.612486             NaN      135.219608
# 3      NaN    male     Non-Smoker  27.423420       99.119829      135.219608
# 4     76.0    male     Non-Smoker  27.423420             NaN      135.219608
# ...    ...     ...            ...        ...             ...             ...
# 9995   NaN    male     Non-Smoker  25.029002      152.540355      137.551451
# 9996   NaN    male     Non-Smoker  27.017487             NaN      135.219608
# 9997  23.0    male         Smoker  27.423420      148.833321      173.931480
# 9998   NaN  female     Non-Smoker  27.423420             NaN      135.219608
# 9999  27.0    male     Non-Smoker  25.454891             NaN      196.083267
#
#       condition
# 0     Pneumonia
# ...

# %%
import numpy as np
df1 = df
df1['blood_pressure'] = np.where((df1['condition'] == 'Diabetic') & (df1['blood_pressure'].isna()), 150, df1['blood_pressure'])

# %%
df1['blood_pressure'] = df1['blood_pressure'].fillna(df1['blood_pressure'].mean())
df1['age'] = df1['age'].fillna(df1['age'].median())

# %%
df1
# Out:
#        age  gender smoking_status        bmi  blood_pressure  glucose_levels  \
# 0     54.0    male     Non-Smoker  27.423420      142.570189      135.219608
# 1     30.0    male     Non-Smoker  27.423420      105.315064      135.219608
# 2     18.0    male     Non-Smoker  35.612486      142.570189      135.219608
# 3     54.0    male     Non-Smoker  27.423420       99.119829      135.219608
# 4     76.0    male     Non-Smoker  27.423420      150.000000      135.219608
# ...    ...     ...            ...        ...             ...             ...
# 9995  54.0    male     Non-Smoker  25.029002      152.540355      137.551451
# 9996  54.0    male     Non-Smoker  27.017487      150.000000      135.219608
# 9997  23.0    male         Smoker  27.423420      148.833321      173.931480
# 9998  54.0  female     Non-Smoker  27.423420      142.570189      135.219608
# 9999  27.0    male     Non-Smoker  25.454891      150.000000      196.083267
#
#       condition
# 0     Pneumonia
# ...

# %%
from sklearn import preprocessing

encoder = preprocessing.LabelEncoder()
df['smoking_status_n'] = encoder.fit_transform(df1['smoking_status'])
df['condition_n'] = encoder.fit_transform(df1['condition'])
df['gender_n'] = encoder.fit_transform(df1['gender'])

# %%
conditon_list = df['condition'].unique()
indx = df['condition_n'].unique()

condition_map = {}

for i in range(len(conditon_list)):
    condition_map[int(indx[i])] = conditon_list[i]

condition_map
# Out:
# {2: 'Pneumonia', 1: 'Diabetic', 0: 'Cancer'}

# %%
df1
# Out:
#        age  gender smoking_status        bmi  blood_pressure  glucose_levels  \
# 0     54.0    male     Non-Smoker  27.423420      142.570189      135.219608
# 1     30.0    male     Non-Smoker  27.423420      105.315064      135.219608
# 2     18.0    male     Non-Smoker  35.612486      142.570189      135.219608
# 3     54.0    male     Non-Smoker  27.423420       99.119829      135.219608
# 4     76.0    male     Non-Smoker  27.423420      150.000000      135.219608
# ...    ...     ...            ...        ...             ...             ...
# 9995  54.0    male     Non-Smoker  25.029002      152.540355      137.551451
# 9996  54.0    male     Non-Smoker  27.017487      150.000000      135.219608
# 9997  23.0    male         Smoker  27.423420      148.833321      173.931480
# 9998  54.0  female     Non-Smoker  27.423420      142.570189      135.219608
# 9999  27.0    male     Non-Smoker  25.454891      150.000000      196.083267
#
# ...

# %%
df2 = df1.drop(['smoking_status', 'condition', 'gender'], axis='columns')
df2
# Out:
#        age        bmi  blood_pressure  glucose_levels  smoking_status_n  \
# 0     54.0  27.423420      142.570189      135.219608                 0
# 1     30.0  27.423420      105.315064      135.219608                 0
# 2     18.0  35.612486      142.570189      135.219608                 0
# 3     54.0  27.423420       99.119829      135.219608                 0
# 4     76.0  27.423420      150.000000      135.219608                 0
# ...    ...        ...             ...             ...               ...
# 9995  54.0  25.029002      152.540355      137.551451                 0
# 9996  54.0  27.017487      150.000000      135.219608                 0
# 9997  23.0  27.423420      148.833321      173.931480                 1
# 9998  54.0  27.423420      142.570189      135.219608                 0
# 9999  27.0  25.454891      150.000000      196.083267                 0
#
#       condition_n  gender_n
# 0               2         1
# 1               1         1
# ...

# %%
X = df2.drop(['condition_n'], axis='columns')
Y = df2['condition_n']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_jobs=20)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=20)

# %%
model.score(x_test, y_test)
# Out:
# 0.719

# %%
pred = model.predict([[24, 24.9, 99, 100, 0, 1]])
condition_map[pred[0]]
# Out:
# c:\Users\Aniket\Documents\Machine Learning\ml_env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 'Diabetic'
